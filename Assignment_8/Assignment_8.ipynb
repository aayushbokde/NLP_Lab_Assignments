# %% [markdown]
# # Install Required Libraries

# %%
# !pip install spacy scikit-learn pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Example Dataset

# %%
data = [
    ("Apple released a new iPhone in California", ["ORG", "PRODUCT", "GPE"]),
    ("Elon Musk founded SpaceX", ["PERSON", "ORG"]),
    ("Barack Obama was born in Hawaii", ["PERSON", "GPE"]),
    ("Google headquarters is in Mountain View", ["ORG", "GPE"]),
]

# %% [markdown]
# # NER Implementation

# %%
import spacy
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# load pretrained NER model
nlp = spacy.load("en_core_web_sm")

# %%
true_labels = []
predicted_labels = []

# process texts
for text, labels in data:

    doc = nlp(text)

    # predicted entity labels
    preds = [ent.label_ for ent in doc.ents]

    # align lengths for evaluation
    min_len = min(len(labels), len(preds))

    true_labels.extend(labels[:min_len])
    predicted_labels.extend(preds[:min_len])

    print("\nText:", text)
    print("Predicted Entities:", [(ent.text, ent.label_) for ent in doc.ents])

# evaluation
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average="macro")
recall = recall_score(true_labels, predicted_labels, average="macro")
f1 = f1_score(true_labels, predicted_labels, average="macro")
# Out:
# Text: Apple released a new iPhone in California
# Predicted Entities: [('Apple', 'ORG'), ('California', 'GPE')]
#
# Text: Elon Musk founded SpaceX
# Predicted Entities: [('Elon Musk founded', 'PERSON')]
#
# Text: Barack Obama was born in Hawaii
# Predicted Entities: [('Barack Obama', 'PERSON'), ('Hawaii', 'GPE')]
#
# Text: Google headquarters is in Mountain View
# Predicted Entities: [('Google', 'ORG'), ('Mountain View', 'GPE')]
# c:\Users\aayus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("\nEvaluation Metrics")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Evaluation Metrics
# Accuracy: 0.8571428571428571
# Precision: 0.6666666666666666
# Recall: 0.75
# F1 Score: 0.7
