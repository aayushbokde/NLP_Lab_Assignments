# %% [markdown]
# # Install Required Libraries

# %%
# !pip install pandas scikit-learn nltk
# Out:
# Requirement already satisfied: pandas in C:\Users\aayus\anaconda3\Lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in C:\Users\aayus\anaconda3\Lib\site-packages (1.6.1)
# Requirement already satisfied: nltk in C:\Users\aayus\anaconda3\Lib\site-packages (3.9.1)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\aayus\anaconda3\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\aayus\anaconda3\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in C:\Users\aayus\anaconda3\Lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\aayus\anaconda3\Lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\aayus\anaconda3\Lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Example Dataset

# %%
data = {
    "text": [
        "Machine learning is amazing and powerful!",
        "Deep learning drives artificial intelligence.",
        "AI is transforming the future of technology.",
        "Natural language processing is a part of AI."
    ],
    "label": [
        "tech",
        "tech",
        "future",
        "tech"
    ]
}

# %% [markdown]
# # Full Implementation

# %%
import pandas as pd
import nltk
import re

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

df = pd.DataFrame(data)

# initialize tools
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

# text cleaning function
def clean_text(text):

    # lowercase
    text = text.lower()

    # remove punctuation
    text = re.sub(r'[^a-z\s]', '', text)

    # tokenize
    words = text.split()

    # remove stopwords
    words = [w for w in words if w not in stop_words]

    # lemmatization
    words = [lemmatizer.lemmatize(w) for w in words]

    return " ".join(words)

# %%
# apply cleaning
df["clean_text"] = df["text"].apply(clean_text)

# label encoding
label_encoder = LabelEncoder()
df["encoded_label"] = label_encoder.fit_transform(df["label"])

# TF-IDF representation
tfidf = TfidfVectorizer()

tfidf_matrix = tfidf.fit_transform(df["clean_text"])

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf.get_feature_names_out()
)

# %%
# save outputs
df.to_csv("cleaned_text.csv", index=False)
tfidf_df.to_csv("tfidf_features.csv", index=False)

print("Cleaned Data:")
print(df)

print("\nTF-IDF Matrix:")
print(tfidf_df)

print("\nOutputs saved:")
print("cleaned_text.csv")
print("tfidf_features.csv")
# Out:
# Cleaned Data:
#                                             text   label  \
# 0      Machine learning is amazing and powerful!    tech
# 1  Deep learning drives artificial intelligence.    tech
# 2   AI is transforming the future of technology.  future
# 3   Natural language processing is a part of AI.    tech
#
#                                     clean_text  encoded_label
# 0            machine learning amazing powerful              1
# 1  deep learning drive artificial intelligence              1
# 2            ai transforming future technology              0
# 3          natural language processing part ai              1
#
# TF-IDF Matrix:
#          ai   amazing  artificial      deep     drive    future  intelligence  \
# 0  0.000000  0.525473    0.000000  0.000000  0.000000  0.000000      0.000000
# 1  0.000000  0.000000    0.465162  0.465162  0.465162  0.000000      0.465162
# 2  0.414289  0.000000    0.000000  0.000000  0.000000  0.525473      0.000000
# 3  0.366739  0.000000    0.000000  0.000000  0.000000  0.000000      0.000000
#
#    language  learning   machine   natural      part  powerful  processing  \
# 0  0.000000  0.414289  0.525473  0.000000  0.000000  0.525473    0.000000
# 1  0.000000  0.366739  0.000000  0.000000  0.000000  0.000000    0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 3  0.465162  0.000000  0.000000  0.465162  0.465162  0.000000    0.465162
#
#    technology  transforming
# 0    0.000000      0.000000
# 1    0.000000      0.000000
# 2    0.525473      0.525473
# 3    0.000000      0.000000
#
# Outputs saved:
# cleaned_text.csv
# tfidf_features.csv
